# %%
from epyt import epanet
import matplotlib.pyplot as plt

# %%
en=epanet('Net2.inp')
# Out:
# EPANET version 20200 loaded (EPyT version 1.1.8).
# Input File Net2.inp loaded successfully.

# %%
en.plot(linksID=True)
plt.show()
# Out:
# /home/wahab901278/anaconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:77: DeprecationWarning: backend2gui is deprecated since IPython 8.24, backends are managed in matplotlib and can be externally registered.
#   warnings.warn(
# /home/wahab901278/anaconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:77: DeprecationWarning: backend2gui is deprecated since IPython 8.24, backends are managed in matplotlib and can be externally registered.
#   warnings.warn(
# /home/wahab901278/anaconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:77: DeprecationWarning: backend2gui is deprecated since IPython 8.24, backends are managed in matplotlib and can be externally registered.
#   warnings.warn(

# %%
en.plot(nodesID=True)
plt.show()

# %%
en.plot(nodesindex=True)
plt.show()

# %%
en.plot(linksindex=True)
plt.show()

# %%
en.plot(nodesID=['9','10','11'])
plt.show()

# %%
en.plot(nodesindex=[9,10,11])
plt.show()

# %%
en.plot(highlightlink=['111','12'])
plt.show()
